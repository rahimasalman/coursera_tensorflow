# %% [markdown]
# <a href="https://colab.research.google.com/github/rahimasalman/coursera_tensorflow/blob/gh-pages/week.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 132.3435
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 64.1357
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 31.2716
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 15.4341
# Epoch 5/500
# 1/1 [==============================] - 0s 9ms/step - loss: 7.7990
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1155
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3358
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4732
# Epoch 9/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0525
# Epoch 10/500
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8447
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7397
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6842
# ...
